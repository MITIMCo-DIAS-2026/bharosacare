-- %%
-- Unity Catalog. Run in the Databricks SQL editor.
-- Creates the curated schema and the Volume that holds Knowledge Assistant files.
-- If your default catalog isn't `workspace`, change it in both statements.

CREATE SCHEMA IF NOT EXISTS workspace.bharosacare;
CREATE VOLUME IF NOT EXISTS workspace.bharosacare.kb;

--niraj
CREATE VOLUME IF NOT EXISTS workspace.bharosacare.raw;
